# %%
import numpy as np
import cv2
from skimage import io
import math
from sklearn.cluster import KMeans
from sklearn.metrics import mean_squared_error
#%matplotlib inline


def extract(image, keypoints):
    result = []
    for key in keypoints:
        cropped = crop(image, key[0], key[1])
        hist = colors_histogam(cropped, 36)
        result.append(hist)
    return result

def distance(descriptor1, descriptor2):
    d1_f = descriptor1.flatten()
    d2_f = descriptor2.flatten()
    best = None
    l = len(descriptor1)
    for i in range(0,l):
        mse = mean_squared_error(d1_f, d2_f)
        if best is None:
            best = mse
            continue
        if mse < best:
            best = mse
        d2_f = np.roll(d2_f, 9)
    return best

def crop(img, y,x):
    i = math.floor(63/2)
    return img[y-i:y+i, x-i:x+i]

def colors_histogam(img, bins):
    hist = []
    angle_step = int(360/bins)
    angles = np.arange(0,360,angle_step)
    layers = 3
    for i, angle in enumerate(angles):
        for layer in range(layers):
            mask = pizza_slice_mask(i,angle_step, layers, layer, (img.shape[0],img.shape[1]))
            hist.append(rgb_means(img,mask))
    return np.array(hist)

def rgb_means(img, mask):
    return cv2.mean(img, mask = mask)
    

    
def pizza_slice_mask(slice_no, angle, layers, layer_no, mask_shape):
    mask = np.zeros(mask_shape, np.uint8)
    mask1 = np.zeros(mask_shape, np.uint8)
    mask2 = np.zeros(mask_shape, np.uint8)
    c = math.floor(mask.shape[1]/2)
    r1 = math.floor(c / layers) * (layer_no + 1)
    if r1 > c - math.floor(c / layers) and r1 < c:
        r1 = c
    cv2.ellipse(
        mask1,
        (c,c),
        (r1,r1),
        0,
        int(slice_no*angle),
        int(slice_no*angle + angle),255,-1)
    r2 = math.floor(c / layers) * layer_no
    if r2 == 0:
        return mask1
    cv2.ellipse(
        mask2,
        (c,c),
        (r2,r2),
        0,
        int(slice_no*angle),
        int(slice_no*angle + angle),255,-1)
    mask = mask1 != mask2
    mask = mask.astype(np.uint8) * np.full(mask_shape, 255)
    return mask.astype(np.uint8)

# %%
from multiprocessing.dummy import Pool 
import sys
import warnings

from os.path import isfile, join, isdir
from os import listdir
import numpy as np
from skimage import transform, io, feature
from sklearn.metrics import roc_auc_score



def coords_in_range(coords, shape):
    c0 = 30 < coords[0] < shape[0] - 30
    c1 = 30 < coords[1] < shape[1] - 30
    return c0 and c1


def filter_out_too_close(coords, r=5):
    result = []
    for c in coords:
        can_add = True
        for c2 in result:
            can_add &= abs(c[0] - c2[0]) > r and abs(c[1] - c2[1]) > r

        if can_add:
            result.append(c)
    return result


def random_coordinates_projections(image, img2, projection_matrix_file, size=100):
    detector = feature.ORB()
    detector.detect(image)
    coordinates = list(filter(lambda x: coords_in_range(x, image.shape), detector.keypoints))
    coordinates = filter_out_too_close(coordinates)[:100]
    homographic_matrix = np.fromfile(projection_matrix_file, dtype=np.float, count=9, sep='\t').reshape((3, 3))

    projection = transform.ProjectiveTransform(homographic_matrix)
    coordinates_revrsed_order = list(map(lambda x: (x[1], x[0]), coordinates))
    transformed_coords = projection(coordinates_revrsed_order)
    transformed_coords = list(map(lambda x: (x[1], x[0]), transformed_coords))

    returns = list(map(lambda x: (int((x[0])), int((x[1]))), transformed_coords))
    coordinates = list(map(lambda x: (int((x[0])), int((x[1]))), coordinates))

    c1 = []
    c2 = []
    for i in range(len(coordinates)):
        if coords_in_range(coordinates[i], image.shape) and coords_in_range(returns[i], img2.shape):
            c1.append(coordinates[i])
            c2.append(returns[i])
            # io.imsave('imgs/' + projection_matrix_file + str(i) + '_1_' + ".png",
            #           image[coordinates[i][0] - 30:coordinates[i][0] + 30,
            #           coordinates[i][1] - 30:coordinates[i][1] + 30])
            # io.imsave('imgs/' + projection_matrix_file + str(i) + '_2_' + ".png",
            #           img2[returns[i][0] - 60:returns[i][0] + 60, returns[i][1] - 60:returns[i][1] + 60])
    print("Created "+ str(len(c1)) + " keypoints for transformation " + projection_matrix_file)
    return c1, c2, img2


def test(img1, img2, matrix_file, skip1):
    first_points, second_points, img2 = random_coordinates_projections(img1, img2, matrix_file)
    first_img_desc = extract(image=img1, keypoints=first_points)
    second_img_desc = extract(image=img2, keypoints=second_points)

    matches = []
    dists = []
    for i in range(len(first_points)):
        if not skip1:
            for j in range(i, len(first_points)):
                if i == j:
                    continue
                dists.append(distance(first_img_desc[i], first_img_desc[j]))
                matches.append(1)
        for j in range(len(second_points)):
            dists.append(distance(first_img_desc[i], second_img_desc[j]))
            if i == j:
                matches.append(0)
            else:
                matches.append(1)

    return matches, dists


def score(testset):
    print(testset)
    img1 = io.imread(join(testset,  'img1.ppm'), as_grey=True)
    score_matches = []
    score_dists = []
    skip1 = False
    for i in range(2, 7):
        img_file = join(testset, 'img' + str(i) + '.ppm')
        matrix_file = join(testset, 'H1to' + str(i) + 'p')
        print("Processing", img_file)

        img2 = io.imread(img_file, as_grey=True)
        matches, dists = test(img1, img2, matrix_file, skip1)
        score_matches += matches
        score_dists += dists
    return score_matches, score_dists



images_sets_path = "C:\\studia\\piro\\deskryptor\\data\\"
sets = [join(images_sets_path, f) for f in listdir(images_sets_path) if isdir(join(images_sets_path, f))]
pool = Pool(4)
print(sets)
# testsets = [
#     'bikes/',
#     'bark.tar/',
#     'graf.tar/',
#     'leuven.tar/',
#     'trees.tar/',
#     'ubc.tar/',
#     'wall.tar/'
# ]
global_matches = []
global_dists = []
s = pool.map(score, sets)
for a in s:
    test_matches, test_dists = a
    print(roc_auc_score(test_matches, test_dists))

print()
# Out:
# ['C:\\studia\\piro\\deskryptor\\data\\bikes', 'C:\\studia\\piro\\deskryptor\\data\\leuven', 'C:\\studia\\piro\\deskryptor\\data\\trees', 'C:\\studia\\piro\\deskryptor\\data\\wall']
# C:\studia\piro\deskryptor\data\bikes
# C:\studia\piro\deskryptor\data\leuvenC:\studia\piro\deskryptor\data\trees
#
# C:\studia\piro\deskryptor\data\wall
# Processing C:\studia\piro\deskryptor\data\leuven\img2.ppm
# Processing C:\studia\piro\deskryptor\data\wall\img2.ppm
# Processing C:\studia\piro\deskryptor\data\trees\img2.ppm
# Processing C:\studia\piro\deskryptor\data\bikes\img2.ppm
# Created 34 keypoints for transformation C:\studia\piro\deskryptor\data\leuven\H1to2p
# Created 38 keypoints for transformation C:\studia\piro\deskryptor\data\bikes\H1to2p
# Created 58 keypoints for transformation C:\studia\piro\deskryptor\data\wall\H1to2p
# Created 58 keypoints for transformation C:\studia\piro\deskryptor\data\trees\H1to2p
# Processing C:\studia\piro\deskryptor\data\leuven\img3.ppm
# Created 34 keypoints for transformation C:\studia\piro\deskryptor\data\leuven\H1to3p
# Processing C:\studia\piro\deskryptor\data\bikes\img3.ppm
# Created 40 keypoints for transformation C:\studia\piro\deskryptor\data\bikes\H1to3p
# Processing C:\studia\piro\deskryptor\data\leuven\img4.ppm
# Created 34 keypoints for transformation C:\studia\piro\deskryptor\data\leuven\H1to4p
# Processing C:\studia\piro\deskryptor\data\wall\img3.ppm
# Created 58 keypoints for transformation C:\studia\piro\deskryptor\data\wall\H1to3p
# Processing C:\studia\piro\deskryptor\data\bikes\img4.ppm
# Created 39 keypoints for transformation C:\studia\piro\deskryptor\data\bikes\H1to4p
# Processing C:\studia\piro\deskryptor\data\trees\img3.ppm
# Created 58 keypoints for transformation C:\studia\piro\deskryptor\data\trees\H1to3p
# Processing C:\studia\piro\deskryptor\data\leuven\img5.ppm
# Created 34 keypoints for transformation C:\studia\piro\deskryptor\data\leuven\H1to5p
# Processing C:\studia\piro\deskryptor\data\bikes\img5.ppm
# Created 38 keypoints for transformation C:\studia\piro\deskryptor\data\bikes\H1to5p
# Processing C:\studia\piro\deskryptor\data\leuven\img6.ppm
# Created 33 keypoints for transformation C:\studia\piro\deskryptor\data\leuven\H1to6p
# Processing C:\studia\piro\deskryptor\data\wall\img4.ppm
# Processing C:\studia\piro\deskryptor\data\bikes\img6.ppm
# Created 56 keypoints for transformation C:\studia\piro\deskryptor\data\wall\H1to4p
# Created 38 keypoints for transformation C:\studia\piro\deskryptor\data\bikes\H1to6p
# Processing C:\studia\piro\deskryptor\data\trees\img4.ppm
# Created 58 keypoints for transformation C:\studia\piro\deskryptor\data\trees\H1to4p
# Processing C:\studia\piro\deskryptor\data\wall\img5.ppm
# Created 55 keypoints for transformation C:\studia\piro\deskryptor\data\wall\H1to5p
# Processing C:\studia\piro\deskryptor\data\trees\img5.ppm
# Created 58 keypoints for transformation C:\studia\piro\deskryptor\data\trees\H1to5p
# Processing C:\studia\piro\deskryptor\data\wall\img6.ppm
# Created 51 keypoints for transformation C:\studia\piro\deskryptor\data\wall\H1to6p
# Processing C:\studia\piro\deskryptor\data\trees\img6.ppm
# Created 58 keypoints for transformation C:\studia\piro\deskryptor\data\trees\H1to6p
# 0.9990902905646193
# 0.7127068088606551
# 0.9371797706712283
# 0.6480906781280209

# %%
io.imread
# Out:
# <function skimage.io._io.imread>

# %%
mask = pizza_slice_mask(0, 90, 3, 2, (100,100))
io.imshow(mask)
io.show()
# Out:
# C:\Users\mikolaj.szal\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
